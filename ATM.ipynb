# %%
restart = 'Y'
chances = 3
balance = 20000.10
while chances >=0:
  pin =int(input('Enter your 4 digit pin:'))
  if pin == 1972:
    print('You have entered pin correctly')
    while restart not in ('n', 'N', 'No', 'no'):
      print('Please Press 1 for your Balance \n')
      print('Please Press 2 for To make withdrawl\n')
      print('Please Press 3 to Pay in \n')
      print('Please press 4 to return card \n' )
      option = int(input('What would you like to choose?'))
      if option ==1:
        print('Your balance is: ', balance, '\n')
        restart = input('Would you like to go back')
        if restart in('n', 'N', 'no', 'No'):
          print('Thank you ')
          break
      elif option == 2:
        option2 = 'y'
        withdrawl = float(input('how much would you like to withdraw? \n Rs50/Rs100/Rs500/Rs1000/Rs2000 for other enter 1:' )) 
        if withdrawl in [50, 100,500,1000,2000]:
          balance = balance - withdrawl
          print('\n Your balance  is now Rs', balance)
          if restart in ('n', 'N', 'no', 'No'):
            print('Thank you ')
            break
          elif withdrawl not in [50, 100,500,1000,2000]:
            print('\n Please enter a valid amount for withdrawl.Please re-try')
            restart = 'y'
          elif withdrawl ==1:
            withdrawl=float(input('Please enter desired amount:'))
      elif option ==3:
        pay_in = float(input('\n How much amount do you want to pay in?'))
        balance += pay_in
        print('\n Your balance is:', balance)
        if restart in ('n', 'N', 'No','no'):
          print('thank you')
      elif option == 4:
        print('\n  Please wait for your card to return')
        print('\n Thank you for your patience')
        break
      else:
        print('Please enter a correct number. \n')
        restart ='y'
  elif pin!= 1972:
    print('Incorrecct Password')
    chances = chances - 1
    if chances == 0:
      print('\n you have reached your limit of your attempts. Please try again later')
      break
# Out:
# Enter your 4 digit pin:1972
# You have entered pin correctly
# Please Press 1 for your Balance
#
# Please Press 2 for To make withdrawl
#
# Please Press 3 to Pay in
#
# Please press 4 to return card
#
# What would you like to choose?2
# how much would you like to withdraw?
#  Rs50/Rs100/Rs500/Rs1000/Rs2000 for other enter 1:1000
#
#  Your balance  is now Rs 19000.1
# Please Press 1 for your Balance
#
# Please Press 2 for To make withdrawl
#
# Please Press 3 to Pay in
#
# Please press 4 to return card
#
# What would you like to choose?3
#
#  How much amount do you want to pay in?100200
#
#  Your balance is: 119200.1
# Please Press 1 for your Balance
#
# Please Press 2 for To make withdrawl
#
# Please Press 3 to Pay in
#
# Please press 4 to return card
#
# What would you like to choose?3
#
#  How much amount do you want to pay in?2000
#
#  Your balance is: 121200.1
# Please Press 1 for your Balance
#
# Please Press 2 for To make withdrawl
#
# Please Press 3 to Pay in
#
# ...
